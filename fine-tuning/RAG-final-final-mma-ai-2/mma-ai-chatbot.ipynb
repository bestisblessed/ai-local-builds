# %%
import os
from langchain_ollama import OllamaEmbeddings
import faiss
import numpy as np
from langchain.document_loaders import CSVLoader
from langchain_community.llms import Ollama
from langchain_ollama import OllamaEmbeddings, OllamaLLM
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.schema.output_parser import StrOutputParser

# %% [markdown]
# This code uses several different models at different steps of the RAG (Retrieval-Augmented Generation) pipeline:
#
# 1. **Embedding Model**:
#    - `OllamaEmbeddings(model="nomic-embed-text:latest")`
#    - This uses the Nomic Embed Text model running through Ollama to convert text into vector embeddings
#    - Used for both document embedding and query embedding
#
# 2. **Vector Database**:
#    - `faiss.IndexFlatL2`
#    - Not a machine learning model per se, but a vector similarity search index from Facebook AI Similarity Search (FAISS)
#    - Uses L2 (Euclidean) distance to find similar vectors
#
# 3. **Language Model (LLM)**:
#    - `Ollama(model="llama3")`
#    - This uses Llama 3 running locally through Ollama
#    - Generates the final response based on the retrieved context and the user's question
#
# The workflow is:
# 1. Documents are embedded using Nomic Embed Text
# 2. User queries are embedded using the same model
# 3. FAISS finds the most similar document embeddings to the query embedding
# 4. The retrieved documents are combined into context
# 5. Llama 3 generates a response using the context and question
#
# This is a fully local RAG implementation, with all models running on your machine through Ollama.

# %%
# Load data
loader = CSVLoader('data-raw/fighter_info.csv')
data = loader.load()

# Embed documents
embeddings = OllamaEmbeddings(model="nomic-embed-text:latest")
embedded_doc = embeddings.embed_documents([text.page_content for text in data])

# Convert to numpy array
embedded_doc = np.array(embedded_doc)

# Create a FAISS index
index = faiss.IndexFlatL2(embedded_doc.shape[1])

# Add vectors to the index
index.add(embedded_doc)

# Save embeddings and index (run this before closing kernel)
np.save('embedded_doc.npy', embedded_doc)
faiss.write_index(index, 'fighter_index.faiss')

# %%
data
# Out:
# [Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 0}, page_content="Fighter: ottman azaitar\nNickname: bulldozer\nBirth Date: feb 20, 1990\nNationality: germany\nHometown: cologne\nAssociation: jupps fight team\nWeight Class: lightweight\nHeight: 5'7\nWins: 13\nLosses: 3\nWin_Decision: 1\nWin_KO: 10\nWin_Sub: 2\nLoss_Decision: 0\nLoss_KO: 3\nLoss_Sub: 0\nFighter_ID: 173073"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 1}, page_content="Fighter: sean woodson\nNickname: the sniper\nBirth Date: jun 7, 1992\nNationality: united states\nHometown: st. louis, missouri\nAssociation: wolves' den training center\nWeight Class: featherweight\nHeight: 6'2\nWins: 13\nLosses: 1\nWin_Decision: 8\nWin_KO: 4\nWin_Sub: 1\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 235563"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 2}, page_content="Fighter: jairzinho rozenstruik\nNickname: bigi boy\nBirth Date: mar 17, 1988\nNationality: suriname\nHometown: paramaribo\nAssociation: american top team\nWeight Class: heavyweight\nHeight: 6'2\nWins: 15\nLosses: 6\nWin_Decision: 2\nWin_KO: 13\nWin_Sub: 0\nLoss_Decision: 3\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 102803"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 3}, page_content="Fighter: drakkar klose\nNickname: -\nBirth Date: mar 9, 1988\nNationality: united states\nHometown: south haven, michigan\nAssociation: fight ready\nWeight Class: lightweight\nHeight: 5'8\nWins: 15\nLosses: 3\nWin_Decision: 9\nWin_KO: 6\nWin_Sub: 0\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 84568"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 4}, page_content="Fighter: dustin jacoby\nNickname: the hanyak\nBirth Date: apr 4, 1988\nNationality: united states\nHometown: arenzville, illinois\nAssociation: factory x\nWeight Class: light heavyweight\nHeight: 6'4\nWins: 20\nLosses: 9\nWin_Decision: 6\nWin_KO: 13\nWin_Sub: 1\nLoss_Decision: 5\nLoss_KO: 2\nLoss_Sub: 2\nFighter_ID: 73825"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 5}, page_content="Fighter: felipe lima\nNickname: jungle boy\nBirth Date: may 7, 1998\nNationality: brazil\nHometown: manaus, amazonas\nAssociation: allstars training center\nWeight Class: featherweight\nHeight: 5'6\nWins: 14\nLosses: 1\nWin_Decision: 7\nWin_KO: 4\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 205627"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 6}, page_content="Fighter: daniel marcos\nNickname: soncora\nBirth Date: mar 7, 1993\nNationality: peru\nHometown: san miguel, lima\nAssociation: los perros sarnosos\nWeight Class: bantamweight\nHeight: 5'7\nWins: 17\nLosses: 0\nWin_Decision: 9\nWin_KO: 8\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 205313"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 7}, page_content="Fighter: vinicius oliveira\nNickname: lokdog\nBirth Date: nov 30, 1995\nNationality: brazil\nHometown: porto alegre, rio grande do sul\nAssociation: sombra team\nWeight Class: bantamweight\nHeight: 5'9\nWins: 22\nLosses: 3\nWin_Decision: 4\nWin_KO: 16\nWin_Sub: 2\nLoss_Decision: 0\nLoss_KO: 3\nLoss_Sub: 0\nFighter_ID: 139517"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 8}, page_content="Fighter: ramon taveras\nNickname: the savage\nBirth Date: jan 9, 1994\nNationality: united states\nHometown: jacksonville, florida\nAssociation: bulldog boxing\nWeight Class: featherweight\nHeight: 5'7\nWins: 10\nLosses: 3\nWin_Decision: 2\nWin_KO: 5\nWin_Sub: 3\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 332055"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 9}, page_content="Fighter: george tokkos\nNickname: tuco\nBirth Date: jun 30, 1990\nNationality: england\nHometown: london, greater london\nAssociation: kill cliff fc\nWeight Class: light heavyweight\nHeight: 6'4\nWins: 10\nLosses: 5\nWin_Decision: 2\nWin_KO: 6\nWin_Sub: 2\nLoss_Decision: 2\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 175999"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 10}, page_content="Fighter: kaan ofli\nNickname: genghis\nBirth Date: jun 19, 1993\nNationality: australia\nHometown: melbourne, victoria\nAssociation: xfc narre warren\nWeight Class: featherweight\nHeight: 5'8\nWins: 11\nLosses: 4\nWin_Decision: 4\nWin_KO: 2\nWin_Sub: 5\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 189203"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 11}, page_content="Fighter: thomas petersen\nNickname: the train\nBirth Date: mar 30, 1995\nNationality: united states\nHometown: farmington, minnesota\nAssociation: spartan mma\nWeight Class: heavyweight\nHeight: 6'1\nWins: 9\nLosses: 3\nWin_Decision: 1\nWin_KO: 7\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 287525"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 12}, page_content="Fighter: sharabutdin magomedov\nNickname: shara bullet\nBirth Date: may 16, 1994\nNationality: russia\nHometown: dagestan\nAssociation: gor mma\nWeight Class: middleweight\nHeight: 6'2\nWins: 15\nLosses: 1\nWin_Decision: 3\nWin_KO: 12\nWin_Sub: 0\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 309711"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 13}, page_content="Fighter: nassourdine imavov\nNickname: the sniper\nBirth Date: mar 1, 1995\nNationality: france\nHometown: paris\nAssociation: mma factory\nWeight Class: middleweight\nHeight: 6'3\nWins: 16\nLosses: 4\nWin_Decision: 5\nWin_KO: 7\nWin_Sub: 4\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 217405"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 14}, page_content="Fighter: billy quarantillo\nNickname: -\nBirth Date: dec 8, 1988\nNationality: united states\nHometown: tampa, florida\nAssociation: gracie tampa south\nWeight Class: featherweight\nHeight: 5'10\nWins: 18\nLosses: 7\nWin_Decision: 5\nWin_KO: 8\nWin_Sub: 5\nLoss_Decision: 3\nLoss_KO: 3\nLoss_Sub: 1\nFighter_ID: 68076"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 15}, page_content="Fighter: sergei pavlovich\nNickname: -\nBirth Date: may 13, 1992\nNationality: russia\nHometown: rostov-on-don, rostov\nAssociation: eagles mma\nWeight Class: heavyweight\nHeight: 6'3\nWins: 19\nLosses: 3\nWin_Decision: 4\nWin_KO: 15\nWin_Sub: 0\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 184051"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 16}, page_content="Fighter: bruno silva\nNickname: bulldog\nBirth Date: mar 16, 1990\nNationality: brazil\nHometown: piracicaba, sao paulo\nAssociation: pitbull brothers\nWeight Class: flyweight\nHeight: 5'4\nWins: 14\nLosses: 6\nWin_Decision: 4\nWin_KO: 6\nWin_Sub: 4\nLoss_Decision: 3\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 118601"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 17}, page_content="Fighter: shamil gaziev\nNickname: -\nBirth Date: feb 10, 1990\nNationality: bahrain\nHometown: manama\nAssociation: khk mma\nWeight Class: heavyweight\nHeight: 6'3\nWins: 14\nLosses: 1\nWin_Decision: 2\nWin_KO: 9\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 313721"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 18}, page_content="Fighter: said nurmagomedov\nNickname: -\nBirth Date: apr 5, 1992\nNationality: russia\nHometown: makhachkala, dagestan\nAssociation: fight club akhmat\nWeight Class: bantamweight\nHeight: 5'8\nWins: 18\nLosses: 4\nWin_Decision: 8\nWin_KO: 4\nWin_Sub: 6\nLoss_Decision: 4\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 103961"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 19}, page_content="Fighter: jamey-lyn horth\nNickname: -\nBirth Date: mar 30, 1990\nNationality: canada\nHometown: squamish, british columbia\nAssociation: the sound martial arts\nWeight Class: flyweight\nHeight: 5'7\nWins: 7\nLosses: 2\nWin_Decision: 2\nWin_KO: 3\nWin_Sub: 2\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 246541"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 20}, page_content="Fighter: miranda maverick\nNickname: fear the\nBirth Date: jul 1, 1997\nNationality: united states\nHometown: springfield, missouri\nAssociation: elevation fight team\nWeight Class: flyweight\nHeight: 5'3\nWins: 15\nLosses: 5\nWin_Decision: 7\nWin_KO: 1\nWin_Sub: 7\nLoss_Decision: 5\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 230031"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 21}, page_content="Fighter: michael johnson\nNickname: the menace\nBirth Date: jun 4, 1986\nNationality: united states\nHometown: springfield, missouri\nAssociation: kill cliff fc\nWeight Class: lightweight\nHeight: 5'10\nWins: 23\nLosses: 19\nWin_Decision: 11\nWin_KO: 10\nWin_Sub: 2\nLoss_Decision: 7\nLoss_KO: 3\nLoss_Sub: 9\nFighter_ID: 68788"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 22}, page_content="Fighter: michael page\nNickname: venom\nBirth Date: apr 7, 1987\nNationality: england\nHometown: london\nAssociation: london shootfighters\nWeight Class: middleweight\nHeight: 6'3\nWins: 23\nLosses: 3\nWin_Decision: 7\nWin_KO: 13\nWin_Sub: 3\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 91937"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 23}, page_content="Fighter: jamal pogues\nNickname: the stormtrooper\nBirth Date: dec 1, 1995\nNationality: united states\nHometown: victorville, california\nAssociation: syndicate mma\nWeight Class: heavyweight\nHeight: 6'2\nWins: 11\nLosses: 5\nWin_Decision: 6\nWin_KO: 4\nWin_Sub: 1\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 2\nFighter_ID: 152993"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 24}, page_content="Fighter: jamahal hill\nNickname: sweet dreams\nBirth Date: may 19, 1991\nNationality: united states\nHometown: grand rapids, michigan\nAssociation: black lion jiu-jitsu\nWeight Class: light heavyweight\nHeight: 6'4\nWins: 12\nLosses: 3\nWin_Decision: 5\nWin_KO: 7\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 3\nLoss_Sub: 0\nFighter_ID: 280417"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 25}, page_content="Fighter: fernando padilla\nNickname: the brave\nBirth Date: dec 15, 1996\nNationality: mexico\nHometown: juarez, chihuahua\nAssociation: team oyama\nWeight Class: featherweight\nHeight: 6'1\nWins: 16\nLosses: 6\nWin_Decision: 2\nWin_KO: 5\nWin_Sub: 9\nLoss_Decision: 5\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 228071"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 26}, page_content="Fighter: zachary reese\nNickname: savage\nBirth Date: mar 24, 1994\nNationality: united states\nHometown: shiner, texas\nAssociation: w4r training center\nWeight Class: middleweight\nHeight: 6'3\nWins: 8\nLosses: 2\nWin_Decision: 1\nWin_KO: 5\nWin_Sub: 2\nLoss_Decision: 0\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 100903"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 27}, page_content="Fighter: damir hadzovic\nNickname: the bosnian bomber\nBirth Date: aug 8, 1986\nNationality: bosnia and herzegovina\nHometown: gorazde\nAssociation: arte suave copenhagen\nWeight Class: lightweight\nHeight: 5'11\nWins: 14\nLosses: 8\nWin_Decision: 4\nWin_KO: 7\nWin_Sub: 3\nLoss_Decision: 5\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 56139"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 28}, page_content="Fighter: raoni barcelos\nNickname: -\nBirth Date: may 1, 1987\nNationality: brazil\nHometown: rio de janeiro, rio de janeiro\nAssociation: laerte barcelos team\nWeight Class: bantamweight\nHeight: 5'7\nWins: 19\nLosses: 5\nWin_Decision: 8\nWin_KO: 8\nWin_Sub: 3\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 94587"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 29}, page_content="Fighter: colby covington\nNickname: chaos\nBirth Date: feb 22, 1988\nNationality: united states\nHometown: springfield, oregon\nAssociation: mma masters\nWeight Class: welterweight\nHeight: 5'11\nWins: 17\nLosses: 5\nWin_Decision: 9\nWin_KO: 4\nWin_Sub: 4\nLoss_Decision: 2\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 57269"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 30}, page_content="Fighter: renato carneiro\nNickname: money moicano\nBirth Date: may 21, 1989\nNationality: brazil\nHometown: brasilia, federal district\nAssociation: first fight center\nWeight Class: lightweight\nHeight: 5'11\nWins: 20\nLosses: 6\nWin_Decision: 8\nWin_KO: 2\nWin_Sub: 10\nLoss_Decision: 1\nLoss_KO: 3\nLoss_Sub: 2\nFighter_ID: 61700"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 31}, page_content="Fighter: navajo stirling\nNickname: -\nBirth Date: nov 7, 1997\nNationality: new zealand\nHometown: auckland\nAssociation: city kickboxing\nWeight Class: light heavyweight\nHeight: 6'4\nWins: 6\nLosses: 0\nWin_Decision: 2\nWin_KO: 4\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 413272"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 32}, page_content="Fighter: diego ferreira\nNickname: -\nBirth Date: jan 18, 1985\nNationality: brazil\nHometown: careiro da varzea, amazonas\nAssociation: fortis mma\nWeight Class: lightweight\nHeight: 5'9\nWins: 19\nLosses: 6\nWin_Decision: 7\nWin_KO: 5\nWin_Sub: 7\nLoss_Decision: 3\nLoss_KO: 3\nLoss_Sub: 0\nFighter_ID: 26358"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 33}, page_content="Fighter: merab dvalishvili\nNickname: the machine\nBirth Date: jan 10, 1991\nNationality: georgia\nHometown: tbilisi\nAssociation: serra-longo fight team\nWeight Class: bantamweight\nHeight: 5'6\nWins: 19\nLosses: 4\nWin_Decision: 15\nWin_KO: 3\nWin_Sub: 1\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 157355"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 34}, page_content="Fighter: bogdan grad\nNickname: the unleashed\nBirth Date: sep 18, 1995\nNationality: austria\nHometown: graz\nAssociation: ettl bros. mma\nWeight Class: featherweight\nHeight: 5'8\nWins: 15\nLosses: 2\nWin_Decision: 3\nWin_KO: 9\nWin_Sub: 3\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 156707"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 35}, page_content="Fighter: jasmine jasudavicius\nNickname: -\nBirth Date: mar 1, 1989\nNationality: canada\nHometown: st. catharines, ontario\nAssociation: niagara top team\nWeight Class: flyweight\nHeight: 5'7\nWins: 13\nLosses: 3\nWin_Decision: 8\nWin_KO: 2\nWin_Sub: 3\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 311001"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 36}, page_content="Fighter: jiri prochazka\nNickname: bjp\nBirth Date: oct 14, 1992\nNationality: czech republic\nHometown: hosteradice\nAssociation: jetsaam gym brno\nWeight Class: light heavyweight\nHeight: 6'4\nWins: 31\nLosses: 5\nWin_Decision: 1\nWin_KO: 27\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 4\nLoss_Sub: 1\nFighter_ID: 97529"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 37}, page_content="Fighter: billy elekana\nNickname: -\nBirth Date: may 28, 1995\nNationality: united states\nHometown: apple valley, california\nAssociation: uprising mma\nWeight Class: light heavyweight\nHeight: 6'2\nWins: 7\nLosses: 2\nWin_Decision: 3\nWin_KO: 3\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 250351"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 38}, page_content="Fighter: muin gafurov\nNickname: tajik\nBirth Date: may 17, 1996\nNationality: tajikistan\nHometown: dushanbe\nAssociation: taj-fighter\nWeight Class: bantamweight\nHeight: 5'7\nWins: 20\nLosses: 6\nWin_Decision: 3\nWin_KO: 10\nWin_Sub: 7\nLoss_Decision: 5\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 182325"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 39}, page_content="Fighter: azamat bekoev\nNickname: king pin\nBirth Date: dec 30, 1995\nNationality: russia\nHometown: vladikavkaz, north ossetia-alania\nAssociation: american top team\nWeight Class: middleweight\nHeight: 5'11\nWins: 19\nLosses: 3\nWin_Decision: 4\nWin_KO: 7\nWin_Sub: 8\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 231875"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 40}, page_content="Fighter: payton talbott\nNickname: -\nBirth Date: sep 9, 1998\nNationality: united states\nHometown: reno, nevada\nAssociation: reno academy of combat\nWeight Class: bantamweight\nHeight: 5'10\nWins: 9\nLosses: 1\nWin_Decision: 1\nWin_KO: 7\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 296553"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 41}, page_content="Fighter: rinya nakamura\nNickname: hybrid\nBirth Date: mar 23, 1995\nNationality: japan\nHometown: saitama\nAssociation: american top team\nWeight Class: bantamweight\nHeight: 5'7\nWins: 9\nLosses: 1\nWin_Decision: 3\nWin_KO: 5\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 386855"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 42}, page_content="Fighter: adrian yanez\nNickname: -\nBirth Date: nov 29, 1993\nNationality: united states\nHometown: la porte, texas\nAssociation: metro fight club\nWeight Class: bantamweight\nHeight: 5'7\nWins: 17\nLosses: 6\nWin_Decision: 4\nWin_KO: 11\nWin_Sub: 2\nLoss_Decision: 4\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 86354"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 43}, page_content="Fighter: joaquin buckley\nNickname: new mansa\nBirth Date: apr 27, 1994\nNationality: united states\nHometown: st. louis, missouri\nAssociation: murcielago mma\nWeight Class: welterweight\nHeight: 5'8\nWins: 21\nLosses: 6\nWin_Decision: 6\nWin_KO: 15\nWin_Sub: 0\nLoss_Decision: 2\nLoss_KO: 4\nLoss_Sub: 0\nFighter_ID: 175481"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 44}, page_content="Fighter: israel adesanya\nNickname: the last stylebender\nBirth Date: jul 22, 1989\nNationality: nigeria\nHometown: lagos\nAssociation: city kickboxing\nWeight Class: middleweight\nHeight: 6'4\nWins: 24\nLosses: 5\nWin_Decision: 8\nWin_KO: 16\nWin_Sub: 0\nLoss_Decision: 2\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 56374"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 45}, page_content="Fighter: fares ziam\nNickname: smile killer\nBirth Date: mar 21, 1997\nNationality: france\nHometown: venissieux\nAssociation: kill cliff fc\nWeight Class: lightweight\nHeight: 6'0\nWins: 17\nLosses: 4\nWin_Decision: 7\nWin_KO: 6\nWin_Sub: 4\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 3\nFighter_ID: 184241"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 46}, page_content="Fighter: mike davis\nNickname: beast boy\nBirth Date: oct 7, 1992\nNationality: united states\nHometown: cairo, new york\nAssociation: fusion x-cel performance\nWeight Class: lightweight\nHeight: 6'0\nWins: 11\nLosses: 3\nWin_Decision: 2\nWin_KO: 7\nWin_Sub: 2\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 202169"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 47}, page_content="Fighter: tatiana suarez\nNickname: -\nBirth Date: dec 19, 1990\nNationality: united states\nHometown: covina, california\nAssociation: millennia mma\nWeight Class: strawweight\nHeight: 5'5\nWins: 10\nLosses: 1\nWin_Decision: 3\nWin_KO: 2\nWin_Sub: 5\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 161107"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 48}, page_content="Fighter: piera rodriguez\nNickname: la fiera\nBirth Date: nov 11, 1992\nNationality: venezuela\nHometown: maracaibo, zulia\nAssociation: black house mma\nWeight Class: strawweight\nHeight: 5'3\nWins: 10\nLosses: 2\nWin_Decision: 5\nWin_KO: 5\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 247469"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 49}, page_content="Fighter: weili zhang\nNickname: magnum\nBirth Date: aug 13, 1989\nNationality: china\nHometown: handan, hebei\nAssociation: fight ready\nWeight Class: strawweight\nHeight: 5'4\nWins: 26\nLosses: 3\nWin_Decision: 7\nWin_KO: 11\nWin_Sub: 8\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 186663"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 50}, page_content="Fighter: gabriel santos\nNickname: mosquitinho\nBirth Date: nov 28, 1996\nNationality: brazil\nHometown: fortaleza, ceara\nAssociation: chute boxe diego lima\nWeight Class: featherweight\nHeight: 5'10\nWins: 12\nLosses: 2\nWin_Decision: 4\nWin_KO: 3\nWin_Sub: 5\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 179211"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 51}, page_content="Fighter: terrance mckinney\nNickname: t.wrecks\nBirth Date: sep 15, 1994\nNationality: united states\nHometown: spokane, washington\nAssociation: warrior camp\nWeight Class: lightweight\nHeight: 5'10\nWins: 16\nLosses: 7\nWin_Decision: 0\nWin_KO: 8\nWin_Sub: 8\nLoss_Decision: 0\nLoss_KO: 5\nLoss_Sub: 2\nFighter_ID: 232591"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 52}, page_content="Fighter: rodolfo bellato\nNickname: trator\nBirth Date: feb 5, 1996\nNationality: brazil\nHometown: sorocaba, sao paulo\nAssociation: knockout squad\nWeight Class: light heavyweight\nHeight: 6'3\nWins: 12\nLosses: 2\nWin_Decision: 1\nWin_KO: 7\nWin_Sub: 4\nLoss_Decision: 0\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 266457"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 53}, page_content="Fighter: justin tafa\nNickname: bad man\nBirth Date: dec 13, 1993\nNationality: australia\nHometown: brisbane, new south wales\nAssociation: ntg fight & fitness\nWeight Class: heavyweight\nHeight: 6'0\nWins: 7\nLosses: 5\nWin_Decision: 0\nWin_KO: 7\nWin_Sub: 0\nLoss_Decision: 3\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 254717"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 54}, page_content="Fighter: umar nurmagomedov\nNickname: -\nBirth Date: jan 3, 1996\nNationality: russia\nHometown: kizilyurt, dagestan\nAssociation: eagles mma\nWeight Class: bantamweight\nHeight: 5'8\nWins: 18\nLosses: 1\nWin_Decision: 9\nWin_KO: 2\nWin_Sub: 7\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 240893"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 55}, page_content="Fighter: hamdy abdelwahab\nNickname: the hammer\nBirth Date: jan 22, 1993\nNationality: united states\nHometown: queens, new york\nAssociation: killer b combat sports academy\nWeight Class: heavyweight\nHeight: 6'2\nWins: 6\nLosses: 0\nWin_Decision: 1\nWin_KO: 5\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 331853"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 56}, page_content="Fighter: francisco prado\nNickname: -\nBirth Date: jun 16, 2002\nNationality: argentina\nHometown: san lorenzo, santa fe\nAssociation: american top team\nWeight Class: welterweight\nHeight: 5'10\nWins: 12\nLosses: 3\nWin_Decision: 0\nWin_KO: 6\nWin_Sub: 6\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 337565"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 57}, page_content="Fighter: jake matthews\nNickname: the celtic kid\nBirth Date: aug 19, 1994\nNationality: australia\nHometown: epping, victoria\nAssociation: nexus\nWeight Class: welterweight\nHeight: 5'11\nWins: 21\nLosses: 7\nWin_Decision: 8\nWin_KO: 5\nWin_Sub: 8\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 3\nFighter_ID: 122139"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 58}, page_content="Fighter: jack jenkins\nNickname: phar\nBirth Date: mar 11, 1993\nNationality: australia\nHometown: melbourne, victoria\nAssociation: absolute mixed martial arts\nWeight Class: featherweight\nHeight: 5'7\nWins: 13\nLosses: 4\nWin_Decision: 4\nWin_KO: 6\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 3\nFighter_ID: 228039"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 59}, page_content="Fighter: tom nolan\nNickname: big train\nBirth Date: mar 8, 2000\nNationality: australia\nHometown: brisbane, queensland\nAssociation: team compton training centre\nWeight Class: lightweight\nHeight: 6'2\nWins: 9\nLosses: 1\nWin_Decision: 4\nWin_KO: 5\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 244655"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 60}, page_content="Fighter: cong wang\nNickname: the joker\nBirth Date: may 15, 1992\nNationality: china\nHometown: shanghai\nAssociation: -\nWeight Class: flyweight\nHeight: 5'7\nWins: 7\nLosses: 1\nWin_Decision: 3\nWin_KO: 2\nWin_Sub: 2\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 413126"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 61}, page_content="Fighter: viacheslav borshchev\nNickname: slava\nBirth Date: jan 8, 1992\nNationality: united states\nHometown: sacramento, california\nAssociation: team alpha male\nWeight Class: lightweight\nHeight: 5'11\nWins: 8\nLosses: 5\nWin_Decision: 2\nWin_KO: 6\nWin_Sub: 0\nLoss_Decision: 4\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 337895"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 62}, page_content="Fighter: dricus du plessis\nNickname: stillknocks\nBirth Date: jan 14, 1994\nNationality: south africa\nHometown: pretoria, gauteng\nAssociation: team cit\nWeight Class: middleweight\nHeight: 6'0\nWins: 23\nLosses: 2\nWin_Decision: 3\nWin_KO: 9\nWin_Sub: 11\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 146193"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 63}, page_content="Fighter: zhu rong\nNickname: -\nBirth Date: mar 7, 2000\nNationality: china\nHometown: aba, sichuan\nAssociation: city kickboxing\nWeight Class: lightweight\nHeight: 5'11\nWins: 26\nLosses: 6\nWin_Decision: 4\nWin_KO: 15\nWin_Sub: 6\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 4\nFighter_ID: 233823"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 64}, page_content="Fighter: quillan salkilld\nNickname: -\nBirth Date: dec 28, 1999\nNationality: australia\nHometown: perth, western australia\nAssociation: luistro combat academy\nWeight Class: lightweight\nHeight: 6'0\nWins: 8\nLosses: 1\nWin_Decision: 2\nWin_KO: 3\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 300317"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 65}, page_content="Fighter: serghei spivac\nNickname: the polar bear\nBirth Date: jan 24, 1995\nNationality: moldova\nHometown: chisinau\nAssociation: polar bear team\nWeight Class: heavyweight\nHeight: 6'3\nWins: 17\nLosses: 5\nWin_Decision: 2\nWin_KO: 7\nWin_Sub: 8\nLoss_Decision: 1\nLoss_KO: 4\nLoss_Sub: 0\nFighter_ID: 179095"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 66}, page_content="Fighter: kody steele\nNickname: -\nBirth Date: apr 21, 1995\nNationality: united states\nHometown: austin, texas\nAssociation: syndicate mma\nWeight Class: lightweight\nHeight: 5'9\nWins: 7\nLosses: 1\nWin_Decision: 2\nWin_KO: 4\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 392962"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 67}, page_content="Fighter: karol rosa\nNickname: -\nBirth Date: dec 30, 1994\nNationality: brazil\nHometown: vila velha, espirito santo\nAssociation: gaea project\nWeight Class: bantamweight\nHeight: 5'7\nWins: 18\nLosses: 7\nWin_Decision: 12\nWin_KO: 4\nWin_Sub: 2\nLoss_Decision: 5\nLoss_KO: 0\nLoss_Sub: 2\nFighter_ID: 115135"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 68}, page_content="Fighter: gilbert burns\nNickname: durinho\nBirth Date: jul 20, 1986\nNationality: brazil\nHometown: niteroi, rio de janeiro\nAssociation: kill cliff fc\nWeight Class: welterweight\nHeight: 5'10\nWins: 22\nLosses: 8\nWin_Decision: 7\nWin_KO: 6\nWin_Sub: 9\nLoss_Decision: 5\nLoss_KO: 3\nLoss_Sub: 0\nFighter_ID: 91727"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 69}, page_content="Fighter: tagir ulanbekov\nNickname: -\nBirth Date: jul 8, 1991\nNationality: russia\nHometown: makhachkala, dagestan\nAssociation: eagles mma\nWeight Class: flyweight\nHeight: 5'7\nWins: 16\nLosses: 2\nWin_Decision: 7\nWin_KO: 1\nWin_Sub: 8\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 149259"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 70}, page_content="Fighter: grant dawson\nNickname: kgd\nBirth Date: feb 20, 1994\nNationality: united states\nHometown: stromsburg, nebraska\nAssociation: american top team\nWeight Class: lightweight\nHeight: 5'10\nWins: 23\nLosses: 2\nWin_Decision: 5\nWin_KO: 5\nWin_Sub: 13\nLoss_Decision: 0\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 103525"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 71}, page_content="Fighter: natalia silva\nNickname: -\nBirth Date: feb 3, 1997\nNationality: brazil\nHometown: timoteo, minas gerais\nAssociation: team borracha\nWeight Class: flyweight\nHeight: 5'5\nWins: 18\nLosses: 5\nWin_Decision: 5\nWin_KO: 5\nWin_Sub: 7\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 2\nFighter_ID: 193033"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 72}, page_content="Fighter: islam makhachev\nNickname: -\nBirth Date: oct 27, 1991\nNationality: russia\nHometown: makhachkala, dagestan\nAssociation: eagles mma\nWeight Class: lightweight\nHeight: 5'10\nWins: 27\nLosses: 1\nWin_Decision: 9\nWin_KO: 5\nWin_Sub: 13\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 76836"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 73}, page_content="Fighter: jessica andrade\nNickname: bate estaca\nBirth Date: sep 25, 1991\nNationality: brazil\nHometown: umuarama, parana\nAssociation: gaea project\nWeight Class: flyweight\nHeight: 5'2\nWins: 26\nLosses: 13\nWin_Decision: 8\nWin_KO: 10\nWin_Sub: 8\nLoss_Decision: 4\nLoss_KO: 5\nLoss_Sub: 4\nFighter_ID: 100715"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 74}, page_content="Fighter: yanal ashmouz\nNickname: red fox\nBirth Date: mar 31, 1995\nNationality: israel\nHometown: tiberias\nAssociation: k dojo warrior tribe\nWeight Class: lightweight\nHeight: 5'9\nWins: 8\nLosses: 1\nWin_Decision: 2\nWin_KO: 4\nWin_Sub: 2\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 252115"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 75}, page_content="Fighter: chris padilla\nNickname: taco\nBirth Date: sep 14, 1995\nNationality: united states\nHometown: gardena, california\nAssociation: california mixed martial arts\nWeight Class: lightweight\nHeight: 5'9\nWins: 15\nLosses: 6\nWin_Decision: 2\nWin_KO: 8\nWin_Sub: 5\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 2\nFighter_ID: 124527"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 76}, page_content="Fighter: vitor petrino\nNickname: icao / merciless / cabuloso\nBirth Date: aug 28, 1997\nNationality: brazil\nHometown: santa luzia, minas gerais\nAssociation: cm system\nWeight Class: light heavyweight\nHeight: 6'3\nWins: 11\nLosses: 2\nWin_Decision: 3\nWin_KO: 7\nWin_Sub: 1\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 255313"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 77}, page_content="Fighter: ricky turcios\nNickname: pretty\nBirth Date: jun 5, 1993\nNationality: united states\nHometown: houston, texas\nAssociation: team alpha male\nWeight Class: bantamweight\nHeight: 5'8\nWins: 12\nLosses: 5\nWin_Decision: 8\nWin_KO: 3\nWin_Sub: 1\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 80671"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 78}, page_content="Fighter: isaac dulgarian\nNickname: the midwest choppa\nBirth Date: jul 4, 1996\nNationality: united states\nHometown: kansas city, missouri\nAssociation: factory x\nWeight Class: featherweight\nHeight: 5'7\nWins: 7\nLosses: 1\nWin_Decision: 0\nWin_KO: 4\nWin_Sub: 3\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 374778"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 79}, page_content="Fighter: cody durden\nNickname: custom made\nBirth Date: mar 29, 1991\nNationality: united states\nHometown: covington, georgia\nAssociation: american top team atlanta\nWeight Class: flyweight\nHeight: 5'7\nWins: 17\nLosses: 7\nWin_Decision: 5\nWin_KO: 6\nWin_Sub: 6\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 4\nFighter_ID: 222325"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 80}, page_content="Fighter: kyle nelson\nNickname: the monster\nBirth Date: apr 20, 1991\nNationality: canada\nHometown: huntsville, ontario\nAssociation: house of champions mma\nWeight Class: lightweight\nHeight: 5'11\nWins: 16\nLosses: 6\nWin_Decision: 6\nWin_KO: 6\nWin_Sub: 4\nLoss_Decision: 2\nLoss_KO: 3\nLoss_Sub: 1\nFighter_ID: 95383"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 81}, page_content="Fighter: josefine lindgren knutsson\nNickname: little thunder\nBirth Date: jan 16, 1996\nNationality: sweden\nHometown: bromma, stockholm\nAssociation: allstars training center\nWeight Class: strawweight\nHeight: 5'3\nWins: 8\nLosses: 1\nWin_Decision: 7\nWin_KO: 1\nWin_Sub: 0\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 378677"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 82}, page_content="Fighter: zha yi\nNickname: -\nBirth Date: jan 8, 1997\nNationality: china\nHometown: aba, sichuan\nAssociation: enbo fight club\nWeight Class: featherweight\nHeight: 5'7\nWins: 25\nLosses: 5\nWin_Decision: 6\nWin_KO: 6\nWin_Sub: 13\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 228277"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 83}, page_content="Fighter: davey grant\nNickname: dangerous\nBirth Date: dec 18, 1985\nNationality: england\nHometown: bishop auckland\nAssociation: syndicate mma\nWeight Class: bantamweight\nHeight: 5'8\nWins: 16\nLosses: 7\nWin_Decision: 3\nWin_KO: 4\nWin_Sub: 9\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 4\nFighter_ID: 30564"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 84}, page_content="Fighter: joel alvarez\nNickname: el fenomeno\nBirth Date: mar 2, 1993\nNationality: spain\nHometown: gijon, asturias\nAssociation: bandog fight club\nWeight Class: lightweight\nHeight: 6'2\nWins: 22\nLosses: 3\nWin_Decision: 0\nWin_KO: 5\nWin_Sub: 17\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 190201"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 85}, page_content="Fighter: reinier de ridder\nNickname: the dutch knight\nBirth Date: sep 7, 1990\nNationality: netherlands\nHometown: breda, north brabant\nAssociation: combat brothers\nWeight Class: middleweight\nHeight: 6'4\nWins: 19\nLosses: 2\nWin_Decision: 2\nWin_KO: 4\nWin_Sub: 13\nLoss_Decision: 0\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 133677"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 86}, page_content="Fighter: brendon marotte\nNickname: the kid\nBirth Date: jan 13, 1997\nNationality: united states\nHometown: hampstead, new hampshire\nAssociation: new england cartel\nWeight Class: featherweight\nHeight: 5'7\nWins: 8\nLosses: 3\nWin_Decision: 2\nWin_KO: 5\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 221671"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 87}, page_content="Fighter: vanessa demopoulos\nNickname: lil monster\nBirth Date: sep 22, 1988\nNationality: united states\nHometown: columbus, ohio\nAssociation: factory x\nWeight Class: strawweight\nHeight: 5'2\nWins: 11\nLosses: 6\nWin_Decision: 6\nWin_KO: 1\nWin_Sub: 4\nLoss_Decision: 5\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 118775"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 88}, page_content="Fighter: felipe dos santos\nNickname: lipe detona\nBirth Date: sep 11, 2000\nNationality: brazil\nHometown: maceio, alagoas\nAssociation: chute boxe diego lima\nWeight Class: flyweight\nHeight: 5'7\nWins: 8\nLosses: 2\nWin_Decision: 3\nWin_KO: 2\nWin_Sub: 3\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 324589"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 89}, page_content="Fighter: andre lima\nNickname: mascote\nBirth Date: feb 4, 1999\nNationality: brazil\nHometown: feira de santana, bahia\nAssociation: team lucas mineiro\nWeight Class: flyweight\nHeight: 5'7\nWins: 10\nLosses: 0\nWin_Decision: 4\nWin_KO: 5\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 201199"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 90}, page_content="Fighter: rose namajunas\nNickname: thug\nBirth Date: jun 29, 1992\nNationality: united states\nHometown: milwaukee, wisconsin\nAssociation: 303 training center\nWeight Class: flyweight\nHeight: 5'5\nWins: 13\nLosses: 7\nWin_Decision: 6\nWin_KO: 2\nWin_Sub: 5\nLoss_Decision: 5\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 69083"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 91}, page_content="Fighter: amir albazi\nNickname: the prince\nBirth Date: oct 27, 1993\nNationality: iraq\nHometown: baghdad\nAssociation: xtreme couture\nWeight Class: flyweight\nHeight: 5'5\nWins: 17\nLosses: 2\nWin_Decision: 3\nWin_KO: 5\nWin_Sub: 9\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 51365"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 92}, page_content="Fighter: dylan budka\nNickname: the mindless hulk\nBirth Date: jan 14, 2000\nNationality: united states\nHometown: findlay, ohio\nAssociation: demolition fight team\nWeight Class: middleweight\nHeight: 5'11\nWins: 7\nLosses: 5\nWin_Decision: 4\nWin_KO: 1\nWin_Sub: 2\nLoss_Decision: 2\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 377018"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 93}, page_content="Fighter: nathan fletcher\nNickname: -\nBirth Date: jan 3, 1998\nNationality: england\nHometown: liverpool\nAssociation: next generation mma liverpool\nWeight Class: featherweight\nHeight: 5'8\nWins: 9\nLosses: 1\nWin_Decision: 1\nWin_KO: 1\nWin_Sub: 7\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 275293"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 94}, page_content="Fighter: mike malott\nNickname: proper\nBirth Date: nov 7, 1991\nNationality: canada\nHometown: halifax, nova scotia\nAssociation: team alpha male\nWeight Class: welterweight\nHeight: 6'1\nWins: 11\nLosses: 2\nWin_Decision: 1\nWin_KO: 4\nWin_Sub: 6\nLoss_Decision: 0\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 79377"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 95}, page_content="Fighter: pedro munhoz\nNickname: the young punisher\nBirth Date: sep 7, 1986\nNationality: brazil\nHometown: sao paulo, sao paulo\nAssociation: american top team\nWeight Class: bantamweight\nHeight: 5'6\nWins: 20\nLosses: 10\nWin_Decision: 7\nWin_KO: 5\nWin_Sub: 8\nLoss_Decision: 10\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 52407"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 96}, page_content="Fighter: youssef zalal\nNickname: the moroccan devil\nBirth Date: sep 4, 1996\nNationality: united states\nHometown: englewood, colorado\nAssociation: factory x\nWeight Class: featherweight\nHeight: 5'10\nWins: 17\nLosses: 5\nWin_Decision: 4\nWin_KO: 4\nWin_Sub: 9\nLoss_Decision: 5\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 229985"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 97}, page_content="Fighter: bernardo sopai\nNickname: the lion king\nBirth Date: sep 25, 2000\nNationality: albania\nHometown: patos\nAssociation: allstars training center\nWeight Class: bantamweight\nHeight: 5'6\nWins: 12\nLosses: 3\nWin_Decision: 2\nWin_KO: 7\nWin_Sub: 3\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 226661"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 98}, page_content="Fighter: aleksandre topuria\nNickname: el conquistador\nBirth Date: jan 28, 1996\nNationality: georgia\nHometown: -\nAssociation: climent club\nWeight Class: bantamweight\nHeight: 5'7\nWins: 6\nLosses: 1\nWin_Decision: 1\nWin_KO: 3\nWin_Sub: 2\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 199421"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 99}, page_content="Fighter: caio machado\nNickname: bigfoot\nBirth Date: jul 20, 1994\nNationality: brazil\nHometown: presidente prudente, sao paulo\nAssociation: franco kickboxing and pankration\nWeight Class: light heavyweight\nHeight: 6'4\nWins: 8\nLosses: 4\nWin_Decision: 2\nWin_KO: 4\nWin_Sub: 2\nLoss_Decision: 4\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 247161"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 100}, page_content="Fighter: brendson ribeiro\nNickname: the gorilla\nBirth Date: aug 9, 1996\nNationality: brazil\nHometown: vila mau, para\nAssociation: brazilian tko\nWeight Class: light heavyweight\nHeight: 6'3\nWins: 16\nLosses: 7\nWin_Decision: 1\nWin_KO: 9\nWin_Sub: 6\nLoss_Decision: 2\nLoss_KO: 3\nLoss_Sub: 2\nFighter_ID: 210539"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 101}, page_content="Fighter: jack shore\nNickname: tank\nBirth Date: feb 6, 1995\nNationality: wales\nHometown: abertillery\nAssociation: tillery combat mma academy\nWeight Class: featherweight\nHeight: 5'9\nWins: 17\nLosses: 3\nWin_Decision: 4\nWin_KO: 4\nWin_Sub: 9\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 2\nFighter_ID: 110177"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 102}, page_content="Fighter: alexander romanov\nNickname: king kong\nBirth Date: dec 11, 1990\nNationality: moldova\nHometown: comrat city\nAssociation: lion club\nWeight Class: heavyweight\nHeight: 6'2\nWins: 18\nLosses: 3\nWin_Decision: 3\nWin_KO: 6\nWin_Sub: 9\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 242931"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 103}, page_content="Fighter: rodrigo nascimento\nNickname: yogi bear/ze colmeia\nBirth Date: nov 26, 1992\nNationality: brazil\nHometown: belo horizonte, minas gerais\nAssociation: american top team\nWeight Class: heavyweight\nHeight: 6'4\nWins: 11\nLosses: 3\nWin_Decision: 3\nWin_KO: 2\nWin_Sub: 6\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 97975"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 104}, page_content="Fighter: ariane lipski\nNickname: the queen\nBirth Date: jan 26, 1994\nNationality: brazil\nHometown: curitiba, parana\nAssociation: lioness mma\nWeight Class: flyweight\nHeight: 5'6\nWins: 17\nLosses: 10\nWin_Decision: 7\nWin_KO: 6\nWin_Sub: 4\nLoss_Decision: 5\nLoss_KO: 4\nLoss_Sub: 1\nFighter_ID: 147487"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 105}, page_content="Fighter: serhiy sidey\nNickname: -\nBirth Date: jul 4, 1996\nNationality: canada\nHometown: burlington, ontario\nAssociation: burlington training centre\nWeight Class: bantamweight\nHeight: 5'10\nWins: 11\nLosses: 2\nWin_Decision: 3\nWin_KO: 7\nWin_Sub: 1\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 220713"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 106}, page_content="Fighter: charles jourdain\nNickname: air\nBirth Date: nov 27, 1995\nNationality: canada\nHometown: beloeil, quebec\nAssociation: academie pro star mma\nWeight Class: bantamweight\nHeight: 5'9\nWins: 16\nLosses: 8\nWin_Decision: 2\nWin_KO: 8\nWin_Sub: 6\nLoss_Decision: 6\nLoss_KO: 1\nLoss_Sub: 1\nFighter_ID: 210843"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 107}, page_content="Fighter: victor henry\nNickname: la mangosta\nBirth Date: may 4, 1987\nNationality: united states\nHometown: los angeles, california\nAssociation: uwf usa\nWeight Class: bantamweight\nHeight: 5'7\nWins: 24\nLosses: 7\nWin_Decision: 9\nWin_KO: 7\nWin_Sub: 8\nLoss_Decision: 6\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 52195"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 108}, page_content="Fighter: garrett armfield\nNickname: -\nBirth Date: oct 9, 1996\nNationality: united states\nHometown: springfield, missouri\nAssociation: springfield fight club\nWeight Class: bantamweight\nHeight: 5'7\nWins: 10\nLosses: 5\nWin_Decision: 2\nWin_KO: 6\nWin_Sub: 2\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 3\nFighter_ID: 254941"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 109}, page_content="Fighter: ivana petrovic\nNickname: -\nBirth Date: jun 11, 1994\nNationality: norway\nHometown: tonsberg\nAssociation: valhall gym\nWeight Class: flyweight\nHeight: 5'8\nWins: 7\nLosses: 2\nWin_Decision: 1\nWin_KO: 3\nWin_Sub: 3\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 331333"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 110}, page_content="Fighter: aiemann zahabi\nNickname: -\nBirth Date: nov 19, 1987\nNationality: canada\nHometown: laval, quebec\nAssociation: tristar gym\nWeight Class: bantamweight\nHeight: 5'8\nWins: 12\nLosses: 2\nWin_Decision: 4\nWin_KO: 6\nWin_Sub: 2\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 121009"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 111}, page_content="Fighter: cody gibson\nNickname: the renegade\nBirth Date: sep 11, 1987\nNationality: united states\nHometown: visalia, california\nAssociation: elite team\nWeight Class: bantamweight\nHeight: 5'10\nWins: 21\nLosses: 10\nWin_Decision: 9\nWin_KO: 7\nWin_Sub: 5\nLoss_Decision: 6\nLoss_KO: 0\nLoss_Sub: 4\nFighter_ID: 38903"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 112}, page_content="Fighter: chad anheliger\nNickname: the monster\nBirth Date: dec 1, 1986\nNationality: canada\nHometown: consort, alberta\nAssociation: champion's creed mma\nWeight Class: bantamweight\nHeight: 5'6\nWins: 13\nLosses: 8\nWin_Decision: 3\nWin_KO: 7\nWin_Sub: 3\nLoss_Decision: 2\nLoss_KO: 0\nLoss_Sub: 6\nFighter_ID: 63370"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 113}, page_content="Fighter: clayton carpenter\nNickname: -\nBirth Date: jun 4, 1996\nNationality: united states\nHometown: glendale, arizona\nAssociation: mma lab\nWeight Class: flyweight\nHeight: 5'5\nWins: 8\nLosses: 1\nWin_Decision: 2\nWin_KO: 2\nWin_Sub: 4\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 208467"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 114}, page_content="Fighter: dustin stoltzfus\nNickname: -\nBirth Date: nov 15, 1991\nNationality: united states\nHometown: lancaster, pennsylvania\nAssociation: frankers fight team\nWeight Class: middleweight\nHeight: 5'11\nWins: 16\nLosses: 6\nWin_Decision: 6\nWin_KO: 3\nWin_Sub: 6\nLoss_Decision: 2\nLoss_KO: 2\nLoss_Sub: 2\nFighter_ID: 113779"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 115}, page_content="Fighter: marc-andre barriault\nNickname: power bar\nBirth Date: feb 18, 1990\nNationality: canada\nHometown: gatineau, quebec\nAssociation: kill cliff fc\nWeight Class: middleweight\nHeight: 6'1\nWins: 16\nLosses: 9\nWin_Decision: 5\nWin_KO: 10\nWin_Sub: 1\nLoss_Decision: 5\nLoss_KO: 3\nLoss_Sub: 1\nFighter_ID: 170803"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 116}, page_content="Fighter: trevin giles\nNickname: the problem\nBirth Date: aug 6, 1992\nNationality: united states\nHometown: houston, texas\nAssociation: w4r training center\nWeight Class: welterweight\nHeight: 6'0\nWins: 16\nLosses: 7\nWin_Decision: 5\nWin_KO: 6\nWin_Sub: 5\nLoss_Decision: 1\nLoss_KO: 3\nLoss_Sub: 3\nFighter_ID: 111237"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 117}, page_content="Fighter: sean strickland\nNickname: tarzan\nBirth Date: feb 27, 1991\nNationality: united states\nHometown: anaheim, california\nAssociation: xtreme couture\nWeight Class: middleweight\nHeight: 6'1\nWins: 29\nLosses: 7\nWin_Decision: 14\nWin_KO: 11\nWin_Sub: 4\nLoss_Decision: 5\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 30452"),
# ...
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 961}, page_content="Fighter: sergey khandozhko\nNickname: honda\nBirth Date: may 19, 1992\nNationality: russia\nHometown: moscow\nAssociation: industrials\nWeight Class: welterweight\nHeight: 6'1\nWins: 27\nLosses: 6\nWin_Decision: 8\nWin_KO: 11\nWin_Sub: 7\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 2\nFighter_ID: 91889"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 962}, page_content="Fighter: dean barry\nNickname: the sniper\nBirth Date: jul 3, 1992\nNationality: ireland\nHometown: dublin\nAssociation: team ryano waterford\nWeight Class: welterweight\nHeight: 5'10\nWins: 4\nLosses: 2\nWin_Decision: 0\nWin_KO: 4\nWin_Sub: 0\nLoss_Decision: 0\nLoss_KO: 0\nLoss_Sub: 1\nFighter_ID: 264071"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 963}, page_content="Fighter: askar askarov\nNickname: bullet\nBirth Date: oct 9, 1992\nNationality: russia\nHometown: khasavyurt, dagestan\nAssociation: fighting eagle\nWeight Class: bantamweight\nHeight: 5'5\nWins: 15\nLosses: 1\nWin_Decision: 4\nWin_KO: 4\nWin_Sub: 7\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 149255"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 964}, page_content="Fighter: kris moutinho\nNickname: -\nBirth Date: aug 9, 1992\nNationality: united states\nHometown: milford, massachusetts\nAssociation: rivera athletic center\nWeight Class: bantamweight\nHeight: 5'7\nWins: 14\nLosses: 6\nWin_Decision: 5\nWin_KO: 6\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 4\nLoss_Sub: 2\nFighter_ID: 126341"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 965}, page_content="Fighter: marlon moraes\nNickname: magic\nBirth Date: apr 26, 1988\nNationality: brazil\nHometown: nova friburgo, rio de janeiro\nAssociation: american top team\nWeight Class: featherweight\nHeight: 5'6\nWins: 23\nLosses: 13\nWin_Decision: 7\nWin_KO: 10\nWin_Sub: 6\nLoss_Decision: 1\nLoss_KO: 10\nLoss_Sub: 2\nFighter_ID: 30936"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 966}, page_content="Fighter: mark striegl\nNickname: mugen\nBirth Date: jun 23, 1988\nNationality: philippines\nHometown: baguio city, benguet\nAssociation: round 1 mma\nWeight Class: featherweight\nHeight: 5'8\nWins: 18\nLosses: 5\nWin_Decision: 4\nWin_KO: 0\nWin_Sub: 14\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 2\nFighter_ID: 50217"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 967}, page_content="Fighter: carlos felipe\nNickname: boi\nBirth Date: jan 12, 1995\nNationality: brazil\nHometown: feira de santana, bahia\nAssociation: life mma\nWeight Class: heavyweight\nHeight: 6'0\nWins: 12\nLosses: 5\nWin_Decision: 6\nWin_KO: 6\nWin_Sub: 0\nLoss_Decision: 5\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 185021"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 968}, page_content="Fighter: bruno souza\nNickname: the tiger\nBirth Date: mar 7, 1996\nNationality: brazil\nHometown: belem, para\nAssociation: machida team\nWeight Class: featherweight\nHeight: 5'10\nWins: 13\nLosses: 3\nWin_Decision: 9\nWin_KO: 1\nWin_Sub: 2\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 231115"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 969}, page_content="Fighter: isaac villanueva\nNickname: hurricane ike\nBirth Date: apr 4, 1984\nNationality: united states\nHometown: houston, texas\nAssociation: 4oz. fight club\nWeight Class: light heavyweight\nHeight: 6'3\nWins: 18\nLosses: 14\nWin_Decision: 3\nWin_KO: 15\nWin_Sub: 0\nLoss_Decision: 1\nLoss_KO: 8\nLoss_Sub: 5\nFighter_ID: 41384"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 970}, page_content="Fighter: ryan hall\nNickname: the wizard\nBirth Date: feb 22, 1985\nNationality: united states\nHometown: falls church, virginia\nAssociation: 50-50 bjj\nWeight Class: featherweight\nHeight: 5'10\nWins: 9\nLosses: 2\nWin_Decision: 4\nWin_KO: 2\nWin_Sub: 3\nLoss_Decision: 1\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 15962"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 971}, page_content="Fighter: kay hansen\nNickname: -\nBirth Date: aug 14, 1999\nNationality: united states\nHometown: whittier, california\nAssociation: 10th planet jiu-jitsu buena park\nWeight Class: strawweight\nHeight: 5'3\nWins: 8\nLosses: 6\nWin_Decision: 2\nWin_KO: 2\nWin_Sub: 4\nLoss_Decision: 5\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 270021"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 972}, page_content="Fighter: gaetano pirrello\nNickname: el tigre\nBirth Date: apr 29, 1992\nNationality: belgium\nHometown: la louviere, hainaut\nAssociation: osman gym\nWeight Class: bantamweight\nHeight: 5'7\nWins: 16\nLosses: 7\nWin_Decision: 2\nWin_KO: 11\nWin_Sub: 3\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 4\nFighter_ID: 54431"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 973}, page_content="Fighter: rogerio bontorin\nNickname: -\nBirth Date: apr 25, 1992\nNationality: brazil\nHometown: adrianopolis, parana\nAssociation: gile ribeiro team\nWeight Class: flyweight\nHeight: 5'5\nWins: 17\nLosses: 5\nWin_Decision: 3\nWin_KO: 3\nWin_Sub: 11\nLoss_Decision: 2\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 132211"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 974}, page_content="Fighter: sara mcmann\nNickname: -\nBirth Date: sep 24, 1980\nNationality: united states\nHometown: gaffney, south carolina\nAssociation: team alpha male\nWeight Class: featherweight\nHeight: 5'5\nWins: 14\nLosses: 7\nWin_Decision: 8\nWin_KO: 1\nWin_Sub: 5\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 4\nFighter_ID: 67094"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 975}, page_content="Fighter: chris gruetzemacher\nNickname: gritz\nBirth Date: jun 16, 1986\nNationality: united states\nHometown: surprise, arizona\nAssociation: 2 knuckle sports mma academy\nWeight Class: lightweight\nHeight: 5'8\nWins: 15\nLosses: 5\nWin_Decision: 5\nWin_KO: 7\nWin_Sub: 3\nLoss_Decision: 0\nLoss_KO: 1\nLoss_Sub: 4\nFighter_ID: 36924"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 976}, page_content="Fighter: maki pitolo\nNickname: coconut bombz\nBirth Date: nov 24, 1990\nNationality: united states\nHometown: nanakuli, hawaii\nAssociation: west oahu mma\nWeight Class: light heavyweight\nHeight: 5'9\nWins: 15\nLosses: 12\nWin_Decision: 4\nWin_KO: 8\nWin_Sub: 3\nLoss_Decision: 2\nLoss_KO: 5\nLoss_Sub: 5\nFighter_ID: 51049"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 977}, page_content="Fighter: chas skelly\nNickname: the scrapper\nBirth Date: may 11, 1985\nNationality: united states\nHometown: keller, texas\nAssociation: kill cliff fc\nWeight Class: featherweight\nHeight: 5'11\nWins: 19\nLosses: 3\nWin_Decision: 5\nWin_KO: 4\nWin_Sub: 10\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 47227"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 978}, page_content="Fighter: timur valiev\nNickname: lucky\nBirth Date: jan 19, 1990\nNationality: russia\nHometown: makhachkala, dagestan\nAssociation: dagfighter\nWeight Class: featherweight\nHeight: 5'6\nWins: 19\nLosses: 4\nWin_Decision: 12\nWin_KO: 5\nWin_Sub: 2\nLoss_Decision: 4\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 70605"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 979}, page_content="Fighter: andre ewell\nNickname: mr. highlight\nBirth Date: jan 21, 1988\nNationality: united states\nHometown: riverside, california\nAssociation: apex mma\nWeight Class: featherweight\nHeight: 5'11\nWins: 18\nLosses: 10\nWin_Decision: 6\nWin_KO: 8\nWin_Sub: 4\nLoss_Decision: 5\nLoss_KO: 2\nLoss_Sub: 3\nFighter_ID: 204397"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 980}, page_content="Fighter: francis ngannou\nNickname: the predator\nBirth Date: sep 5, 1986\nNationality: france\nHometown: paris\nAssociation: xtreme couture\nWeight Class: heavyweight\nHeight: 6'4\nWins: 18\nLosses: 3\nWin_Decision: 1\nWin_KO: 13\nWin_Sub: 4\nLoss_Decision: 3\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 152341"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 981}, page_content="Fighter: yaozong hu\nNickname: totoro\nBirth Date: apr 7, 1995\nNationality: china\nHometown: beijing\nAssociation: tiger muay thai\nWeight Class: light heavyweight\nHeight: 6'3\nWins: 3\nLosses: 3\nWin_Decision: 0\nWin_KO: 2\nWin_Sub: 1\nLoss_Decision: 1\nLoss_KO: 0\nLoss_Sub: 2\nFighter_ID: 251779"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 982}, page_content="Fighter: aspen ladd\nNickname: -\nBirth Date: mar 1, 1995\nNationality: united states\nHometown: folsom, california\nAssociation: mma gold fight team\nWeight Class: featherweight\nHeight: 5'6\nWins: 12\nLosses: 5\nWin_Decision: 4\nWin_KO: 6\nWin_Sub: 2\nLoss_Decision: 4\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 141393"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 983}, page_content="Fighter: darren stewart\nNickname: the dentist\nBirth Date: dec 30, 1990\nNationality: england\nHometown: london, greater london\nAssociation: the mma clinic\nWeight Class: light heavyweight\nHeight: 6'0\nWins: 16\nLosses: 10\nWin_Decision: 6\nWin_KO: 9\nWin_Sub: 1\nLoss_Decision: 6\nLoss_KO: 2\nLoss_Sub: 2\nFighter_ID: 128141"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 984}, page_content="Fighter: sean soriano\nNickname: -\nBirth Date: oct 6, 1989\nNationality: united states\nHometown: providence, rhode island\nAssociation: kill cliff fc\nWeight Class: featherweight\nHeight: 5'9\nWins: 15\nLosses: 9\nWin_Decision: 3\nWin_KO: 8\nWin_Sub: 4\nLoss_Decision: 3\nLoss_KO: 1\nLoss_Sub: 5\nFighter_ID: 61682"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 985}, page_content="Fighter: luigi vendramini\nNickname: the italian stallion\nBirth Date: jan 16, 1996\nNationality: brazil\nHometown: brasilia, federal district\nAssociation: factory x\nWeight Class: lightweight\nHeight: 5'10\nWins: 11\nLosses: 3\nWin_Decision: 0\nWin_KO: 6\nWin_Sub: 5\nLoss_Decision: 1\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 225223"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 986}, page_content="Fighter: casey kenney\nNickname: -\nBirth Date: mar 20, 1991\nNationality: united states\nHometown: tuscon, arizona\nAssociation: rise combat sports\nWeight Class: bantamweight\nHeight: 5'7\nWins: 16\nLosses: 4\nWin_Decision: 9\nWin_KO: 2\nWin_Sub: 5\nLoss_Decision: 4\nLoss_KO: 0\nLoss_Sub: 0\nFighter_ID: 211031"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 987}, page_content="Fighter: volkan oezdemir\nNickname: no time\nBirth Date: sep 19, 1989\nNationality: switzerland\nHometown: fribourg\nAssociation: fight move academy\nWeight Class: light heavyweight\nHeight: 6'1\nWins: 20\nLosses: 8\nWin_Decision: 5\nWin_KO: 13\nWin_Sub: 2\nLoss_Decision: 4\nLoss_KO: 2\nLoss_Sub: 2\nFighter_ID: 58503"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 988}, page_content="Fighter: collin anglin\nNickname: -\nBirth Date: feb 20, 1993\nNationality: united states\nHometown: south lyon, michigan\nAssociation: scorpion fighting system\nWeight Class: featherweight\nHeight: 5'9\nWins: 10\nLosses: 6\nWin_Decision: 3\nWin_KO: 7\nWin_Sub: 0\nLoss_Decision: 2\nLoss_KO: 4\nLoss_Sub: 0\nFighter_ID: 280415"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 989}, page_content="Fighter: khama worthy\nNickname: the deathstar\nBirth Date: oct 15, 1986\nNationality: united states\nHometown: pittsburgh, pennsylvania\nAssociation: the academy pittsburgh\nWeight Class: lightweight\nHeight: 5'11\nWins: 20\nLosses: 11\nWin_Decision: 6\nWin_KO: 11\nWin_Sub: 3\nLoss_Decision: 1\nLoss_KO: 9\nLoss_Sub: 1\nFighter_ID: 82557"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 990}, page_content="Fighter: kai kamaka iii\nNickname: the fighting hawaiian\nBirth Date: jan 5, 1995\nNationality: united states\nHometown: waipahu, hawaii\nAssociation: xtreme couture\nWeight Class: featherweight\nHeight: 5'7\nWins: 14\nLosses: 6\nWin_Decision: 12\nWin_KO: 1\nWin_Sub: 1\nLoss_Decision: 4\nLoss_KO: 2\nLoss_Sub: 0\nFighter_ID: 117585"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 991}, page_content="Fighter: mallory martin\nNickname: -\nBirth Date: jan 29, 1994\nNationality: united states\nHometown: denver, colorado\nAssociation: elevation fight team\nWeight Class: strawweight\nHeight: 5'4\nWins: 10\nLosses: 6\nWin_Decision: 6\nWin_KO: 2\nWin_Sub: 2\nLoss_Decision: 4\nLoss_KO: 0\nLoss_Sub: 2\nFighter_ID: 200771"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 992}, page_content="Fighter: gina mazany\nNickname: danger\nBirth Date: aug 19, 1988\nNationality: united states\nHometown: anchorage, alaska\nAssociation: glory mma & fitness\nWeight Class: flyweight\nHeight: 5'6\nWins: 8\nLosses: 6\nWin_Decision: 3\nWin_KO: 3\nWin_Sub: 2\nLoss_Decision: 1\nLoss_KO: 4\nLoss_Sub: 1\nFighter_ID: 36287"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 993}, page_content="Fighter: bethe correia\nNickname: pitbull\nBirth Date: jun 22, 1983\nNationality: brazil\nHometown: campina grande, paraiba\nAssociation: cm system\nWeight Class: bantamweight\nHeight: 5'4\nWins: 11\nLosses: 6\nWin_Decision: 9\nWin_KO: 2\nWin_Sub: 0\nLoss_Decision: 3\nLoss_KO: 2\nLoss_Sub: 1\nFighter_ID: 103069"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 994}, page_content="Fighter: alexis davis\nNickname: ally-gator\nBirth Date: oct 4, 1984\nNationality: canada\nHometown: port colborne, ontario\nAssociation: combat sports academy\nWeight Class: bantamweight\nHeight: 5'6\nWins: 21\nLosses: 11\nWin_Decision: 11\nWin_KO: 2\nWin_Sub: 8\nLoss_Decision: 7\nLoss_KO: 3\nLoss_Sub: 1\nFighter_ID: 22071"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 995}, page_content="Fighter: sijara eubanks\nNickname: sarj\nBirth Date: apr 27, 1985\nNationality: united states\nHometown: brick, new jersey\nAssociation: mark henry boxing\nWeight Class: bantamweight\nHeight: 5'4\nWins: 7\nLosses: 7\nWin_Decision: 4\nWin_KO: 3\nWin_Sub: 0\nLoss_Decision: 6\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 193533"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 996}, page_content="Fighter: shamil gamzatov\nNickname: umar\nBirth Date: aug 9, 1990\nNationality: russia\nHometown: makhachkala, dagestan\nAssociation: russian top team\nWeight Class: light heavyweight\nHeight: 6'2\nWins: 14\nLosses: 3\nWin_Decision: 4\nWin_KO: 5\nWin_Sub: 5\nLoss_Decision: 2\nLoss_KO: 1\nLoss_Sub: 0\nFighter_ID: 136875"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 997}, page_content="Fighter: danilo marques\nNickname: -\nBirth Date: dec 26, 1985\nNationality: brazil\nHometown: sao paulo, sao paulo\nAssociation: kings mma\nWeight Class: heavyweight\nHeight: 6'6\nWins: 15\nLosses: 6\nWin_Decision: 4\nWin_KO: 4\nWin_Sub: 7\nLoss_Decision: 1\nLoss_KO: 5\nLoss_Sub: 0\nFighter_ID: 172145"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 998}, page_content="Fighter: jamey simmons\nNickname: the afro samurai\nBirth Date: sep 11, 1992\nNationality: united states\nHometown: milwaukee, wisconsin\nAssociation: pura vida bjj\nWeight Class: bantamweight\nHeight: 5'5\nWins: 7\nLosses: 4\nWin_Decision: 2\nWin_KO: 4\nWin_Sub: 1\nLoss_Decision: 0\nLoss_KO: 2\nLoss_Sub: 2\nFighter_ID: 237195"),
#  Document(metadata={'source': 'data-raw/fighter_info.csv', 'row': 999}, page_content="Fighter: impa kasanganay\nNickname: tshilobo\nBirth Date: jan 17, 1994\nNationality: united states\nHometown: fort lauderdale, florida\nAssociation: kill cliff fc\nWeight Class: light heavyweight\nHeight: 6'0\nWins: 18\nLosses: 5\nWin_Decision: 9\nWin_KO: 5\nWin_Sub: 4\nLoss_Decision: 2\nLoss_KO: 3\nLoss_Sub: 0\nFighter_ID: 310489"),
#  ...]

# %%
index
# Out:
# <faiss.swigfaiss.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x1379914a0> >

# %%
embedded_doc.shape
# Out:
# (2646, 768)

# %%
# Generate a query vector
# query_text = "Find and tell me Jon Jones method of victories from his career"
query_text = "Tell me about Leon Edwards"
query_vector = embeddings.embed_query(query_text)
query_vector = np.array([query_vector])

# Perform similarity search
distances, indices = index.search(query_vector, k=5)

# Print results
print("Similarity distances:", distances)
print("Indices of similar documents:", indices)
# Out:
# Similarity distances: [[0.6606034  0.8654603  0.871382   0.92637384 0.94489515]]
# Indices of similar documents: [[ 549 1242 1723 1709  337]]

# %%
# Iterate over results and print matching documents
for i, idx in enumerate(indices[0]):
    print(f"Document {i+1} (Index: {idx}):")
    print(data[idx])
# Out:
# Document 1 (Index: 549):
# page_content='Fighter: leon edwards
# Nickname: rocky
# Birth Date: aug 25, 1991
# Nationality: england
# Hometown: erdington, west midlands
# Association: team renegade
# Weight Class: welterweight
# Height: 6'0
# Wins: 22
# Losses: 4
# Win_Decision: 12
# Win_KO: 7
# Win_Sub: 3
# Loss_Decision: 3
# Loss_KO: 0
# Loss_Sub: 0
# Fighter_ID: 62665' metadata={'source': 'data-raw/fighter_info.csv', 'row': 549}
# Document 2 (Index: 1242):
# page_content='Fighter: te edwards
# Nickname: t
# Birth Date: sep 11, 1990
# Nationality: united states
# Hometown: phoenix, arizona
# Association: mma lab
# Weight Class: lightweight
# Height: 5'8
# Wins: 6
# Losses: 3
# Win_Decision: 0
# Win_KO: 6
# Win_Sub: 0
# Loss_Decision: 2
# Loss_KO: 1
# Loss_Sub: 0
# Fighter_ID: 156303' metadata={'source': 'data-raw/fighter_info.csv', 'row': 1242}
# Document 3 (Index: 1723):
# page_content='Fighter: yves edwards
# Nickname: thugjitsu master
# Birth Date: sep 30, 1976
# Nationality: united states
# Hometown: woodlands, texas
# Association: american top team
# Weight Class: lightweight
# Height: 5'10
# Wins: 42
# Losses: 22
# Win_Decision: 9
# Win_KO: 17
# Win_Sub: 16
# Loss_Decision: 12
# Loss_KO: 4
# Loss_Sub: 6
# Fighter_ID: 344' metadata={'source': 'data-raw/fighter_info.csv', 'row': 1723}
# Document 4 (Index: 1709):
# page_content='Fighter: justin edwards
# Nickname: fast eddy
# Birth Date: jan 26, 1983
# Nationality: united states
# Hometown: cincinnati, ohio
# Association: team jorge gurgel
# Weight Class: lightweight
# Height: 5'10
# Wins: 10
# Losses: 7
# Win_Decision: 1
# Win_KO: 1
# Win_Sub: 8
# Loss_Decision: 3
# Loss_KO: 3
# Loss_Sub: 1
# Fighter_ID: 37452' metadata={'source': 'data-raw/fighter_info.csv', 'row': 1709}
# Document 5 (Index: 337):
# page_content='Fighter: joselyne edwards
# Nickname: la pantera
# Birth Date: sep 29, 1995
# Nationality: panama
# Hometown: panama city
# Association: kings mma
# Weight Class: featherweight
# Height: 5'6
# Wins: 14
# Losses: 6
# Win_Decision: 5
# Win_KO: 5
# Win_Sub: 4
# Loss_Decision: 5
# Loss_KO: 0
# Loss_Sub: 1
# Fighter_ID: 156643' metadata={'source': 'data-raw/fighter_info.csv', 'row': 337}

# %%
# Use retrieved documents with an LLM for better answers
# Optional

llm = Ollama(model="llama3")

# Create prompt template
prompt_template = """
You are an MMA expert assistant. Use the following information to answer the question.

Context:
{context}

Question: {question}

Answer:
"""

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template
)

# Create chain
# chain = LLMChain(llm=llm, prompt=prompt)
chain = prompt | llm | StrOutputParser()

# Get the most similar documents
similar_docs = [data[idx] for idx in indices[0]]

# Combine retrieved documents into context
context = "\n\n".join([doc.page_content for doc in similar_docs])

# Get response
# response = chain.run(context=context, question=query_text)
response = chain.invoke({"context": context, "question": query_text})

print("\nAI Response:")
print(response)
# Out:
# AI Response:
# Merab Dvalishvili, also known as "The Machine". Here's a breakdown of his profile:
#
# **Age:** As of January 2023, Merab is 32 years old.
#
# **Nationality:** Georgian
#
# **Hometown:** Tbilisi, Georgia
#
# **Association:** Serra-Longo Fight Team
#
# **Weight Class:** Bantamweight (135 lbs)
#
# **Height:** 5'6" (168 cm)
#
# **Record:**
#
# * **Wins:** 19
# 	+ **Decisions:** 15
# 	+ **KOs/TKOs:** 3
# 	+ **Submissions:** 1
# * **Losses:** 4
# 	+ **Decisions:** 3
# 	+ **KOs/TKOs:** 0
# 	+ **Submissions:** 1
#
# Overall, Merab has an impressive record with a high winning percentage. His ability to secure decisions is one of his strengths, indicating that he can outlast and outmaneuver his opponents over the course of three rounds. While he doesn't have a significant number of KOs or submissions, his all-around skillset suggests that he's well-rounded and capable of adapting to different situations in fights.
#
# Would you like me to compare Merab with Enrique Marin (Wasabi) or Marcos Mariano (Dhalsim)?

# %% [markdown]
# ---

# %%
# Reload and ask new question

# query_text = "Analyze and tell me about Aljamain Sterling"
query_text = "Analyze and tell me about Merab"
 
loader = CSVLoader('data-raw/fighter_info.csv')
data = loader.load()
embeddings = OllamaEmbeddings(model="nomic-embed-text:latest")
embedded_doc = np.load('embedded_doc.npy')
index = faiss.read_index('fighter_index.faiss')
llm = Ollama(model="llama3")
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    You are an MMA expert assistant. Use the following information to answer the question.
    
    Context:
    {context}
    
    Question: 
    {question}
    
    Answer:
    """
    )
# chain = LLMChain(llm=llm, prompt=prompt)
chain = prompt | llm | StrOutputParser()
query_vector = embeddings.embed_query(query_text)
query_vector = np.array([query_vector])
k = 3  
distances, indices = index.search(query_vector, k)
similar_docs = [data[idx] for idx in indices[0]]
print(f"Query: {query_text}")
print(f"\nSimilarity distances: {distances}")
print(f"Indices of similar documents: {indices}")
for i, doc in enumerate(similar_docs):
    print(f"\nDocument {i+1} (Distance: {distances[0][i]:.4f}):")
    print(doc.page_content)
context = "\n\n".join([doc.page_content for doc in similar_docs])
response = chain.invoke({"context": context, "question": query_text})
print("\nAI Response:")
print(response)
# print(response['text'])
# Out:
# Query: Analyze and tell me about Merab
#
# Similarity distances: [[0.9572598 1.0666069 1.0700512]]
# Indices of similar documents: [[  33 1533 1294]]
#
# Document 1 (Distance: 0.9573):
# Fighter: merab dvalishvili
# Nickname: the machine
# Birth Date: jan 10, 1991
# Nationality: georgia
# Hometown: tbilisi
# Association: serra-longo fight team
# Weight Class: bantamweight
# Height: 5'6
# Wins: 19
# Losses: 4
# Win_Decision: 15
# Win_KO: 3
# Win_Sub: 1
# Loss_Decision: 3
# Loss_KO: 0
# Loss_Sub: 1
# Fighter_ID: 157355
#
# Document 2 (Distance: 1.0666):
# Fighter: enrique marin
# Nickname: wasabi
# Birth Date: sep 2, 1986
# Nationality: spain
# Hometown: seville, andalusia
# Association: sutemi mma
# Weight Class: welterweight
# Height: 5'10
# Wins: 13
# Losses: 7
# Win_Decision: 6
# Win_KO: 3
# Win_Sub: 4
# Loss_Decision: 3
# Loss_KO: 1
# Loss_Sub: 3
# Fighter_ID: 27077
#
# Document 3 (Distance: 1.0701):
# Fighter: marcos mariano
# Nickname: dhalsim
# Birth Date: oct 12, 1986
# Nationality: brazil
# Hometown: guarulhos, sao paulo
# Association: killer bees
# Weight Class: lightweight
# Height: 6'1
# Wins: 7
# Losses: 7
# Win_Decision: 3
# Win_KO: 2
# Win_Sub: 2
# Loss_Decision: 2
# Loss_KO: 1
# Loss_Sub: 4
# Fighter_ID: 182785
#
# AI Response:
# Merab Dvalishvili, also known as "The Machine"! Let's dive into his stats and background.
#
# **Background**
#
# * Born on January 10, 1991, in Tbilisi, Georgia
# * Represents the Serra-Longo Fight Team
# * Currently competes at the Bantamweight division (135 lbs)
#
# **Fight Record**
#
# * Overall record: 19-4
# * Win-loss ratio: 82.2% (wins) / 17.8% (losses)
# * Method of wins:
# 	+ Decision wins: 15 (79.0%)
# 	+ KO/TKO wins: 3 (15.8%)
# 	+ Submission wins: 1 (5.3%)
# * Method of losses:
# 	+ Decision losses: 3 (75.0%)
# 	+ KO/TKO losses: 0 (0%)
# 	+ Submission losses: 1 (25.0%)
#
# **Physical Attributes**
#
# * Height: 5'6" (168 cm)
# * Weight class: Bantamweight (135 lbs)
#
# As "The Machine", Merab Dvalishvili has an impressive record with a strong emphasis on decision wins. His ability to outlast opponents and secure victories via decision is a significant asset in his arsenal. With 15 decision wins, he's demonstrated his endurance and capacity to control fights.
#
# Keep in mind that this analysis focuses solely on Merab's profile and does not consider specific matchups or potential strategies for future fights.

# %%
# Interactive Version ^

loader = CSVLoader('data-raw/fighter_info.csv')
data = loader.load()
embeddings = OllamaEmbeddings(model="nomic-embed-text:latest")
embedded_doc = np.load('embedded_doc.npy')
index = faiss.read_index('fighter_index.faiss')
llm = OllamaLLM(model="llama3")
prompt = PromptTemplate(
    input_variables=["context", "history", "question"],
    template="""
You are an MMA expert assistant. Use the following information to answer the question.

Context information:
{context}

Conversation history:
{history}

Current question: {question}

Answer:
"""
)
chain = prompt | llm | StrOutputParser()
conversation_history = []
def format_history():
    """Format conversation history for the prompt"""
    if not conversation_history:
        return "No previous conversation."
    formatted = []
    for i, (q, a) in enumerate(conversation_history):
        formatted.append(f"Question: {q}")
        formatted.append(f"Answer: {a}")
    return "\n".join(formatted)
def query_mma_assistant(query_text, k=3):
    """Process a query and return a response"""
    query_vector = embeddings.embed_query(query_text)
    query_vector = np.array([query_vector])
    distances, indices = index.search(query_vector, k)
    similar_docs = [data[idx] for idx in indices[0]]
    print(f"\nFound {len(similar_docs)} relevant fighter profiles:")
    for i, doc in enumerate(similar_docs):
        fighter_name = doc.page_content.split("\n")[0].replace("Fighter: ", "")
        print(f"- {fighter_name} (Similarity: {distances[0][i]:.4f})")
    context = "\n\n".join([doc.page_content for doc in similar_docs])
    history = format_history()
    response = chain.invoke({
        "context": context, 
        "history": history,
        "question": query_text
    })
    conversation_history.append((query_text, response))
    return response
print("\n===== MMA Fighter Assistant =====")
print("Ask questions about MMA fighters. Type 'quit' to exit or 'clear' to reset conversation.")
while True:
    query = input("\nYour question: ")
    if query.lower() in ['quit', 'exit', 'q']:
        print("Goodbye!")
        break
    if query.lower() in ['clear', 'reset']:
        conversation_history = []
        print("Conversation history cleared.")
        continue
    if not query.strip():
        continue
    response = query_mma_assistant(query)
    print("\nMMA Assistant:")
    print(response)

# %% [markdown]
# ---

# %% [markdown]
# # Models Used in Your MMA RAG System and Potential Alternatives
#
# Your current RAG implementation uses several models at different stages of the pipeline. Here's a breakdown of what you're using and some improved alternatives you could try:
#
# ## 1. Embedding Model
# **Current**: `OllamaEmbeddings(model="nomic-embed-text:latest")`
#
# **Improved Alternatives**:
# - **BGE Embeddings**: `from langchain_community.embeddings import HuggingFaceEmbeddings; embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-large-en-v1.5")`
# - **E5 Embeddings**: `HuggingFaceEmbeddings(model_name="intfloat/e5-large-v2")`
# - **Instructor Embeddings**: `from langchain_community.embeddings import HuggingFaceInstructEmbeddings; embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl")`
#
# ## 2. Vector Database
# **Current**: `faiss.IndexFlatL2`
#
# **Improved Alternatives**:
# - **FAISS with HNSW**: `index = faiss.IndexHNSWFlat(dimension, M=16)`
# - **Chroma DB**: `from langchain_community.vectorstores import Chroma; db = Chroma.from_documents(documents, embeddings)`
# - **Qdrant**: `from langchain_community.vectorstores import Qdrant; db = Qdrant.from_documents(documents, embeddings)`
#
# ## 3. Language Model (LLM)
# **Current**: `Ollama(model="llama3")`
#
# **Improved Alternatives**:
# - **Llama 2 70B**: `Ollama(model="llama2:70b")` - Better performance across all metrics compared to smaller Llama models [source](https://huggingface.co/meta-llama/Llama-2-7b-hf)
# - **Mistral 7B**: `Ollama(model="mistral")` - Outperforms Llama2-13B on all metrics despite being smaller [source](https://www.e2enetworks.com/blog/mistral-7b-vs-llama2-which-performs-better-and-why)
# - **Mixtral 8x7B**: `Ollama(model="mixtral")`
# - **Llama 3 8B/70B**: `Ollama(model="llama3:8b")` or `Ollama(model="llama3:70b")`
#
# ## Performance Considerations
#
# According to the search results, Llama 2 70B significantly outperforms the 7B variant across all benchmarks:
# - **MMLU**: 68.9% vs 45.3%
# - **BBH**: 51.2% vs 32.6%
# - **TruthfulQA**: 50.18% vs 33.29%
#
# Mistral 7B is particularly noteworthy as it outperforms Llama2-13B on all metrics while being smaller, which means:
# - Faster inference
# - Lower memory requirements
# - Better throughput
#
# For your MMA chatbot, using Mistral 7B could provide a good balance of performance and efficiency, especially if you're running these models locally.
